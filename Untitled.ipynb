# %%
import requests
import pandas as pd
import numpy as np
import altair as alt
from bs4 import BeautifulSoup
import re

# %%
URL = "https://www.bharatkalachar.com/34th-margazhi-mahothsav.html"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")
table = soup.find_all("table")

# %%
rows = []
for child in soup.find_all('table')[0].children:
    row = []
    for td in child:
        try:
            row.append(td.text)
        except:
            continue
    if len(row) > 0:
        rows.append(row)

df = pd.DataFrame(rows[1:], columns=rows[0])


df1 = pd.DataFrame()
for i in range(7):
    df2 = pd.DataFrame()
    df2['Name'] = df['NAME'].str.split("\r\n", expand = True)[i]
    df2['Instrument'] = df['SPECIALITY'].str.split("\r\n", expand = True)[i]
    df1 = df1.append(df2)
df = df.merge(df1, how = 'outer', right_index = True, left_index = True )

df.DATE = df.DATE.str.strip()
df[['Date', 'Month', 'Year']] = df.DATE.str.split(".", expand = True)
df.Date = pd.to_numeric(df.Date)
df.Month = pd.to_numeric(df.Month)
df.Year = pd.to_numeric(df.Year)

df[['Date', 'Month', 'Year']] = df[['Date', 'Month', 'Year']].ffill()
df.TIME = df.TIME.str.replace('.', ":")
df.TIME = df.TIME.str.replace(',', ":")
df.TIME = df.TIME.str.replace('a', "A")
df.TIME = df.TIME.str.replace('p', "P")
df.TIME = df.TIME.str.replace('m', "M")
df.TIME = df.TIME.str.replace(" ", "")
df['Date'] = df.Date.astype(int).astype(str)
df['Month'] = df.Month.astype(int).astype(str)
df['Year'] = df.Year.astype(int).astype(str)
df['startDateTime'] = pd.to_datetime(df.Year + "-" + df.Month + "-" +  df.Date + " " + df.TIME)

df['Name'] = df.Name.astype(str)
df['Instrument'] = df.Instrument.astype(str)
df['sabha'] = "bharatkalachar"
df['address'] = "No.16.Thirumalai Pillai Street, T-Nagar, 17, Thirumalai Pillai Rd, T. Nagar, Chennai, Tamil Nadu 600017, India"
df['lat'] = 13.049258196982954
df['long'] = 80.2410428821105
df.Name = df.Name.str.replace("\n", "")
df.Name = df.Name.str.strip()
df.Instrument = df.Instrument.str.strip()
df.Name = df.Name.str.replace('    ', "nan")
df.Instrument = df.Instrument.str.replace("\t", "")
df.Instrument = df.Instrument.str.replace("\n", "")
df = df.query('Name != "nan"')

# %%
df[["sabha", "startDateTime", "Name", "Instrument", "TICKETS", 'lat', 'long', 'address']]
# Out:
#              sabha       startDateTime  \
# 0   bharatkalachar 2022-12-16 16:30:00
# 0   bharatkalachar 2022-12-16 16:30:00
# 0   bharatkalachar 2022-12-16 16:30:00
# 0   bharatkalachar 2022-12-16 16:30:00
# 0   bharatkalachar 2022-12-16 16:30:00
# ..             ...                 ...
# 76  bharatkalachar 2023-01-14 19:15:00
# 77  bharatkalachar 2023-01-15 16:00:00
# 78  bharatkalachar 2023-01-15 19:15:00
# 78  bharatkalachar 2023-01-15 19:15:00
# 78  bharatkalachar 2023-01-15 19:15:00
#
#                                          Name      Instrument  \
# 0                Pravaham' an all woman band.
# 0                           Anjani Srinivasan          Veenai
# 0                Rangappriya Sankaranarayanan          Violin
# 0                           Aswini Srinivasan       Mridangam
# 0                             Charu Hariharan     Percussions
# ..                                        ...             ...
# 76                                                        nan
# 77           Spoorthi Rao & Svarathmika-Vocal      Vocal Duet
# 78  Parashah presents Thirumazhilai Kuravanji  Bharathanatyam
# 78        Roja Kannan & Priya Murle and party             nan
# 78                                                        nan
#
#             TICKETS        lat       long  \
# 0   All ARE WELCOME  13.049258  80.241043
# 0   All ARE WELCOME  13.049258  80.241043
# 0   All ARE WELCOME  13.049258  80.241043
# 0   All ARE WELCOME  13.049258  80.241043
# 0   All ARE WELCOME  13.049258  80.241043
# ..              ...        ...        ...
# 76         TICKETED  13.049258  80.241043
# 77         TICKETED  13.049258  80.241043
# 78         TICKETED  13.049258  80.241043
# 78         TICKETED  13.049258  80.241043
# 78         TICKETED  13.049258  80.241043
#
#                                               address
# 0   No.16.Thirumalai Pillai Street, T-Nagar, 17, T...
# 0   No.16.Thirumalai Pillai Street, T-Nagar, 17, T...
# 0   No.16.Thirumalai Pillai Street, T-Nagar, 17, T...
# 0   No.16.Thirumalai Pillai Street, T-Nagar, 17, T...
# 0   No.16.Thirumalai Pillai Street, T-Nagar, 17, T...
# ..                                                ...
# 76  No.16.Thirumalai Pillai Street, T-Nagar, 17, T...
# 77  No.16.Thirumalai Pillai Street, T-Nagar, 17, T...
# 78  No.16.Thirumalai Pillai Street, T-Nagar, 17, T...
# 78  No.16.Thirumalai Pillai Street, T-Nagar, 17, T...
# 78  No.16.Thirumalai Pillai Street, T-Nagar, 17, T...
#
# [238 rows x 8 columns]

# %%
df.Instrument.value_counts()
# Out:
#                       35
# nan                   35
# Mridangam             27
# Vocal                 24
# Violin                23
# Bharathanatyam        22
# Ghatam                11
# Vocal Duet             4
# Kanjira                4
# Dance Drama            4
# VIOLIN                 3
# Keyboard               3
# MRIDANGAM              3
# KANJIRA                2
# Harikatha              2
# Bharatahnatyam         2
# Mandolin               2
# Tabla                  2
# VOCAL                  1
# Handsonic & Ghatam     1
# Veenai                 1
# Mandolin duet          1
# Namasankirtan          1
# Kuchipudi              1
# Tabla & Morsing        1
# Addl.Percussn          1
# Veena Fusion           1
# Piano                  1
# Special Effects        1
# Violin duet            1
# Guitar                 1
# Drama                  1
# Dolki                  1
# Violin Duet            1
# Harmonium              1
# Rhythm Pad             1
# Vocal duet             1
# Narration              1
# Mridngam               1
# Percussion             1
# Percussions            1
# Nattuvangam            1
# Madhuraveena           1
# Music                  1
# Vocal support          1
# Bass guitar            1
# Pads                   1
# Fusion music           1
# Name: Instrument, dtype: int64
